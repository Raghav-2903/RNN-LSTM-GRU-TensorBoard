# %% [markdown]
# <a href="https://colab.research.google.com/github/Raghav-2903/RNN-LSTM-GRU-TensorBoard/blob/main/Copy_of_RNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/seattle-weather.csv')

# %%
df.head()
# Out:
#          date  precipitation  temp_max  temp_min  wind  weather
# 0  2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1  2012-01-02           10.9      10.6       2.8   4.5     rain
# 2  2012-01-03            0.8      11.7       7.2   2.3     rain
# 3  2012-01-04           20.3      12.2       5.6   4.7     rain
# 4  2012-01-05            1.3       8.9       2.8   6.1     rain

# %%
df.isnull().sum()
# Out:
# date             0
# precipitation    0
# temp_max         0
# temp_min         0
# wind             0
# weather          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#coulmn Open converted into numpy array
training_set = df.iloc[:,2:3].values
training_set
# Out:
# array([[12.8],
#        [10.6],
#        [11.7],
#        ...,
#        [ 7.2],
#        [ 5.6],
#        [ 5.6]])

# %%
len(training_set)
# Out:
# 1461

# %%
def df_to_XY(df,window_size=10):
 X_train=[]
 y_train=[]

 for i in range(10,len(training_set)):
    X_train.append(training_set[i-10:i,0])
    y_train.append(training_set[i,0])

 X_train, y_train = np.array(X_train), np.array(y_train)
 return X_train, y_train

# %%
WINDOW = 10
X,y = df_to_XY(df,WINDOW)
print(len(X),len(y))
X_train = X[:800]
y_train = y[:800]
X_val = X[800:1000]
y_val = y[800:1000]
X_test = X[1000:]
x_test = y[1000:]
# Out:
# 1451 1451

# %%
#Reshaping(To add new dimensions)
X_train = np.reshape(X_train,(X_train.shape[0],X_train.shape[1],1))
X_val = np.reshape(X_val,(X_val.shape[0],X_val.shape[1],1))
X_test = np.reshape(X_test,(X_test.shape[0],X_test.shape[1],1))

# %%
#Building the RNN
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout

# %%
regressor = Sequential()

# %%
#Addinf the first LSTM layer and some Dropout regularisation
regressor.add(LSTM(units=50, return_sequences = True, input_shape=(X_train.shape[1], 1)))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units=50, return_sequences = True))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units=50, return_sequences = True))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units=50))
regressor.add(Dropout(0.2))

#Output layer
regressor.add(Dense(units=1))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
#Compiling
regressor.compile(optimizer='adam',loss='mean_squared_error')

# %%
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

# %%
#fitting the rnn to the training set
regressor.compile(optimizer='adam',loss='mean_squared_error')
history=regressor.fit(X_train,y_train,validation_data=(X_val,y_val),epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 58ms/step - loss: 248.5981 - val_loss: 256.1187
# Epoch 2/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 112.4474 - val_loss: 169.7039
# Epoch 3/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 76.7537 - val_loss: 139.3608
# Epoch 4/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 66.6155 - val_loss: 119.9884
# Epoch 5/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 59.8498 - val_loss: 106.0892
# Epoch 6/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 55.2731 - val_loss: 96.1997
# Epoch 7/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 57.5267 - val_loss: 89.5296
# Epoch 8/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 55.4033 - val_loss: 84.9675
# Epoch 9/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 53.8769 - val_loss: 81.3388
# Epoch 10/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 54.0219 - val_loss: 79.5954
# Epoch 11/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 58.7619 - val_loss: 77.5350
# Epoch 12/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 51.1551 - val_loss: 77.6278
# Epoch 13/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 54.6708 - val_loss: 76.4688
# Epoch 14/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 53.6286 - val_loss: 76.2377
# Epoch 15/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 53.6615 - val_loss: 76.3019
# Epoch 16/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 55.7346 - val_loss: 76.0426
# Epoch 17/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 53.2104 - val_loss: 76.7742
# Epoch 18/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 56.9821 - val_loss: 76.3655
# Epoch 19/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 51.1505 - val_loss: 76.1049
# Epoch 20/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 49.5269 - val_loss: 75.9949
# Epoch 21/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 55.7742 - val_loss: 75.6241
# Epoch 22/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 50.8221 - val_loss: 75.9733
# Epoch 23/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 54.0272 - val_loss: 76.7000
# Epoch 24/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 55.6893 - val_loss: 75.8076
# Epoch 25/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 51.1761 - val_loss: 77.6129
# Epoch 26/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 53.9535 - val_loss: 76.8691
# Epoch 27/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 40.4552 - val_loss: 62.1482
# Epoch 28/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 31.9423 - val_loss: 52.9720
# Epoch 29/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 26.7500 - val_loss: 41.8318
# Epoch 30/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 19.9557 - val_loss: 37.0046
# Epoch 31/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 19.4867 - val_loss: 31.0376
# Epoch 32/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 16.9926 - val_loss: 28.9630
# Epoch 33/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 17.7402 - val_loss: 23.8094
# Epoch 34/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 12.9569 - val_loss: 22.3496
# Epoch 35/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 12.6928 - val_loss: 20.1738
# Epoch 36/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 12.8817 - val_loss: 18.5194
# Epoch 37/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 12.9500 - val_loss: 19.3152
# Epoch 38/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 14.2743 - val_loss: 17.1240
# Epoch 39/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 10.8549 - val_loss: 16.3791
# Epoch 40/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 10.4420 - val_loss: 15.2102
# Epoch 41/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 11.6791 - val_loss: 14.6866
# Epoch 42/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 10.2641 - val_loss: 14.4781
# Epoch 43/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 10.6018 - val_loss: 14.2301
# Epoch 44/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 11.1196 - val_loss: 14.4482
# Epoch 45/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 10.0958 - val_loss: 13.3812
# Epoch 46/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 9.9997 - val_loss: 12.4763
# Epoch 47/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 10.1858 - val_loss: 13.8807
# Epoch 48/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 10.5389 - val_loss: 12.8064
# Epoch 49/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 11.0398 - val_loss: 12.6280
# Epoch 50/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 10.6162 - val_loss: 13.1063
# Epoch 51/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 9.9807 - val_loss: 11.7289
# Epoch 52/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 9.1299 - val_loss: 11.8147
# Epoch 53/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 8.9475 - val_loss: 13.0181
# Epoch 54/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 9.5700 - val_loss: 11.3131
# Epoch 55/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 8.5788 - val_loss: 11.6652
# Epoch 56/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 11.6211 - val_loss: 11.3347
# Epoch 57/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 9.0406 - val_loss: 11.1734
# Epoch 58/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 8.2328 - val_loss: 10.7949
# Epoch 59/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 8.5446 - val_loss: 10.8137
# Epoch 60/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 10.8314 - val_loss: 11.9733
# Epoch 61/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 10.4405 - val_loss: 11.0236
# Epoch 62/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 8.8209 - val_loss: 10.7597
# Epoch 63/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 9.5059 - val_loss: 10.9026
# Epoch 64/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 8.7731 - val_loss: 10.5539
# Epoch 65/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 8.7802 - val_loss: 10.4926
# Epoch 66/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 8.9149 - val_loss: 10.4747
# Epoch 67/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 8.9689 - val_loss: 10.4755
# Epoch 68/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 8.5627 - val_loss: 10.8837
# Epoch 69/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 8.7375 - val_loss: 10.8792
# Epoch 70/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 8.9279 - val_loss: 11.9697
# Epoch 71/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 8.7647 - val_loss: 10.4090
# Epoch 72/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 9.3527 - val_loss: 11.6456
# Epoch 73/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 9.8512 - val_loss: 10.2503
# Epoch 74/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 9.3089 - val_loss: 10.3795
# Epoch 75/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 10.1026 - val_loss: 10.1645
# Epoch 76/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 9.2918 - val_loss: 11.0638
# Epoch 77/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 9.2558 - val_loss: 10.2339
# Epoch 78/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 8.9605 - val_loss: 12.2706
# Epoch 79/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 9.0694 - val_loss: 10.3180
# Epoch 80/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 7.7102 - val_loss: 10.2646
# Epoch 81/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 7.9694 - val_loss: 10.7591
# Epoch 82/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 8.6704 - val_loss: 10.2879
# Epoch 83/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 8.4766 - val_loss: 10.2015
# Epoch 84/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 8.4282 - val_loss: 9.8714
# Epoch 85/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 9.2615 - val_loss: 10.1173
# Epoch 86/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 9.0694 - val_loss: 10.5527
# Epoch 87/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 9.9697 - val_loss: 10.3580
# Epoch 88/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 8.8357 - val_loss: 10.0499
# Epoch 89/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 8.7903 - val_loss: 11.6899
# Epoch 90/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 10.3872 - val_loss: 11.3035
# Epoch 91/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 8.7705 - val_loss: 10.0583
# Epoch 92/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 8.3435 - val_loss: 12.0306
# Epoch 93/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 8.9343 - val_loss: 9.7837
# Epoch 94/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 8.2820 - val_loss: 9.7955
# Epoch 95/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 7.8998 - val_loss: 9.8219
# Epoch 96/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 8.0557 - val_loss: 10.0764
# Epoch 97/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 8.5813 - val_loss: 9.9547
# Epoch 98/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 8.0254 - val_loss: 10.0311
# Epoch 99/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 8.6818 - val_loss: 9.6591
# Epoch 100/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 9.3981 - val_loss: 10.2558

# %%
his = pd.DataFrame(history.history)

# %%
his.head()
# Out:
#          loss    val_loss
# 0  209.257629  256.118744
# 1   97.515411  169.703903
# 2   73.989777  139.360779
# 3   63.811718  119.988449
# 4   59.754345  106.089211

# %%
import seaborn as sns
his.columns
history_loss = his[['loss', 'val_loss']]


fig,axes = plt.subplots(2,1,figsize=(14,8))
plt.subplot(2,1,1)
plt.title("Loss & Val Loss")
sns.lineplot(history_loss,palette="flare");

# %%
train_pred = regressor.predict(X_train).flatten()
val_pred = regressor.predict(X_val).flatten()
test_pred = regressor.predict(X_test).flatten()
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 161ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step

# %%
pred = np.concatenate([train_pred,val_pred,test_pred])
df_pred = pd.DataFrame(df["temp_max"].copy())
df_pred.columns=["actual"]
df_pred = df_pred[WINDOW:]
df_pred["predicted"] = pred

fig,axes = plt.subplots(2,1,figsize=(14,8),dpi=400)

plt.subplot(2,1,1)
plt.title("Validation Results")
sns.lineplot(df_pred[800:],alpha=0.8,palette="flare",linestyle=None);

plt.subplot(2,1,2)
plt.title("Test Results")
sns.lineplot(df_pred[1000:],alpha=0.8,palette="flare",linestyle=None);
